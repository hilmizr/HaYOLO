# %% [markdown]
# # Clone Repository

# %%
# !rm -rf HaYOLO
# !git clone -b gsconvns-fix --single-branch https://github.com/hilmizr/HaYOLO.git
# Out:
# Cloning into 'HaYOLO'...
# remote: Enumerating objects: 38887, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 38887 (delta 18), reused 11 (delta 11), pack-reused 38864 (from 3)
# Receiving objects: 100% (38887/38887), 23.20 MiB | 19.19 MiB/s, done.
# Resolving deltas: 100% (28268/28268), done.

# %%
# !git pull
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# # Install Libraries

# %%
# !pip install roboflow gdown thop
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.66-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.6.15)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.0.2)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.2.1)
# Collecting pillow-heif>=0.18.0 (from roboflow)
#   Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.4.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from thop) (2.6.0+cu124)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.58.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->thop) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->thop)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->thop)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->thop)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->thop)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->thop)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->thop)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->thop) (3.0.2)
# Downloading roboflow-1.1.66-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 5.5 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.8 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 51.3 MB/s eta 0:00:00
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 134.0 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 115.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 99.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 111.3 MB/s eta 0:00:00
# Installing collected packages: filetype, python-dotenv, pillow-heif, opencv-python-headless, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, idna, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, roboflow, thop
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed filetype-1.2.0 idna-3.7 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 opencv-python-headless-4.10.0.84 pillow-heif-0.22.0 python-dotenv-1.1.0 roboflow-1.1.66 thop-0.1.1.post2209072238

# %% [markdown]
# # Import Libraries

# %%
import os
import shutil
import yaml
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns
from scipy.spatial.distance import jensenshannon
from IPython.display import display
from PIL import Image
import cv2
import json
from shutil import copyfile
import sys
import os
import requests
from pathlib import Path
import random
import pathlib

# %% [markdown]
# # Setup Custom YOLO

# %%
sys.path.append("/content/HaYOLO")
# Import YOLO directly from the ultralytics packagea
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics.models import yolo
from ultralytics.nn.modules import GSConv, C3Ghost, CBAM, GSConvns, GSBottleneck, GSBottleneckC, VoVGSCSP, VoVGSCSPC, ASPP, RFB, C3GS, C3k2GS, C3k2Ghost
from ultralytics.nn.modules import C2PSAGhost, C2PSAGS, C2fPSAGhost, C2fPSAGS, C2PSACBAM, C2fPSACBAM

# %% [markdown]
# ## Define Custom Architecture

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic
@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# ["yolov11n_baseline", "yolov11n_cbam_c3k2ghost", "yolov11n_cbam_ghostconv_c3k2ghost", "yolov11n_cbam_ghostconv", "yolov11n_cbam"]
model_name = "yolov11n_C2PSA"
yaml_path = f"/content/HaYOLO/custom_yaml/final_variants/{model_name}.yaml"

# %%
# %%writetemplate {yaml_path}
# # Ultralytics 🚀 AGPL-3.0 License - https://ultralytics.com/license
#
# # Ultralytics YOLO11 object detection model with P3/8 - P5/32 outputs
# # Model docs: https://docs.ultralytics.com/models/yolo11
# # Task docs: https://docs.ultralytics.com/tasks/detect
#
# # Parameters
# nc: 80 # number of classes
# scales: # model compound scaling constants, i.e. 'model=yolo11n.yaml' will call yolo11.yaml with scale 'n'
#   # [depth, width, max_channels]
#   n: [0.50, 0.25, 1024] # summary: 181 layers, 2624080 parameters, 2624064 gradients, 6.6 GFLOPs
#   s: [0.50, 0.50, 1024] # summary: 181 layers, 9458752 parameters, 9458736 gradients, 21.7 GFLOPs
#   m: [0.50, 1.00, 512] # summary: 231 layers, 20114688 parameters, 20114672 gradients, 68.5 GFLOPs
#   l: [1.00, 1.00, 512] # summary: 357 layers, 25372160 parameters, 25372144 gradients, 87.6 GFLOPs
#   x: [1.00, 1.50, 512] # summary: 357 layers, 56966176 parameters, 56966160 gradients, 196.0 GFLOPs
#
# # YOLO11n backbone
# backbone:
#   # [from, repeats, module, args]
#   - [-1, 1, Conv, [64, 3, 2]] # 0-P1/2
#   - [-1, 1, Conv, [128, 3, 2]] # 1-P2/4
#   - [-1, 2, C3k2, [256, False, 0.25]]
#   - [-1, 1, Conv, [256, 3, 2]] # 3-P3/8
#   - [-1, 2, C3k2, [512, False, 0.25]]
#   - [-1, 1, Conv, [512, 3, 2]] # 5-P4/16
#   - [-1, 2, C3k2, [512, True]]
#   - [-1, 1, Conv, [1024, 3, 2]] # 7-P5/32
#   - [-1, 2, C3k2, [1024, True]]
#   - [-1, 1, SPPF, [1024, 5]] # 9
#   - [-1, 2, C2PSA, [1024]] # 10
#
# # YOLO11n head
# head:
#   - [-1, 1, nn.Upsample, [None, 2, "nearest"]]
#   - [[-1, 6], 1, Concat, [1]] # cat backbone P4
#   - [-1, 2, C3k2, [512, False]] # 13
#
#   - [-1, 1, nn.Upsample, [None, 2, "nearest"]]
#   - [[-1, 4], 1, Concat, [1]] # cat backbone P3
#   - [-1, 2, C3k2, [256, False]] # 16 (P3/8-small)
#
#   - [-1, 1, Conv, [256, 3, 2]]
#   - [[-1, 13], 1, Concat, [1]] # cat head P4
#   - [-1, 2, C3k2, [512, False]] # 19 (P4/16-medium)
#
#   - [-1, 1, Conv, [512, 3, 2]]
#   - [[-1, 10], 1, Concat, [1]] # cat head P5
#   - [-1, 2, C3k2, [1024, True]] # 22 (P5/32-large)
#
#   - [[16, 19, 22], 1, Detect, [nc]] # Detect(P3, P4, P5)

# %% [markdown]
# ## Compile Model

# %%
modif_model = YOLO(yaml_path)

# %% [markdown]
# # Setup Dataset

# %% [markdown]
# ## Download Dataset

# %%
DATASET_TYPE = "ENHANCED_COMBINED"

# %%
if DATASET_TYPE == "ORIGINAL":
  FILE_ID = "1zkqt7GQViegIqZnObSA87GsWrBn22I6c"
  data_yaml_path = r'/content/DUO-dataset-2/content/DUO-dataset-2/content/DUO_yolo_70_20_10/data.yaml'
  test_folder = r'/content/DUO-dataset-2/content/DUO-dataset-2/content/DUO_yolo_70_20_10/test/images'
elif DATASET_TYPE == "ENHANCED_HILMI":
  FILE_ID = "1fPJKhHSQz2J2vq6T2F2wnQ7lR52DlM4X"
  data_yaml_path = r'/content/DUO-dataset-2/content/DUO-dataset-github-enhanced-hilmi/data.yaml'
  test_folder = r'/content/DUO-dataset-2/content/DUO-dataset-github-enhanced-hilmi/test/images'
elif DATASET_TYPE == "ENHANCED_COMBINED":
  FILE_ID = "1bCAlw4CmJUXvXlnx6_NkXtbfVPYQyC8Q"
  data_yaml_path = r'/content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/data.yaml'
  test_folder = r'/content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images'

# %%
OUTPUT = "DUO-dataset-2.zip"

# %%
import gdown
gdown.download(id=FILE_ID, output=OUTPUT, quiet=False)
# !unzip -q DUO-dataset-2.zip -d DUO-dataset-2
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1bCAlw4CmJUXvXlnx6_NkXtbfVPYQyC8Q
# From (redirected): https://drive.google.com/uc?id=1bCAlw4CmJUXvXlnx6_NkXtbfVPYQyC8Q&confirm=t&uuid=85cbce61-a870-4d1a-8a4a-5eb6517761df
# To: /content/DUO-dataset-2.zip
# 100%|██████████| 981M/981M [00:08<00:00, 111MB/s]

# %% [markdown]
# # Modeling

# %%
modif_model.train(
    data=data_yaml_path,
    epochs=300,

    # spatial / batch
    imgsz=640,            # will train on 640×640 images (3 channels assumed)
    batch=16,             # batch size

    # optimizer & LR schedule
    optimizer='SGD',      # stochastic gradient descent
    lr0=0.01,             # initial learning rate
    lrf=0.1,              # final learning rate factor (multiplied by lr0 at end of training)
    momentum=0.937,       # SGD momentum
    weight_decay=0.0005,  # L2 regularization factor

    # early stopping & checkpointing
    patience=100,
    save=True,
    save_period=-1,

    device=0
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.158 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.143 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=300, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.1, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/HaYOLO/custom_yaml/final_variants/yolov11n_C2PSA.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/HaYOLO/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 21.3MB/s]
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431452  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# YOLOv11n_C2PSA summary: 181 layers, 2,590,620 parameters, 2,590,604 gradients, 6.4 GFLOPs
#
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 102MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2772.3±1390.7 MB/s, size: 145.1 KB)
# train: Scanning /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/train/labels... 4901 images, 38 backgrounds, 0 corrupt: 100%|██████████| 4901/4901 [00:03<00:00, 1450.26it/s]
# train: New cache created: /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 678.9±424.1 MB/s, size: 130.8 KB)
# val: Scanning /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/val/labels... 1515 images, 15 backgrounds, 0 corrupt: 100%|██████████| 1515/1515 [00:01<00:00, 1171.90it/s]
# val: New cache created: /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/val/labels.cache
# Plotting labels to /content/HaYOLO/runs/detect/train/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /content/HaYOLO/runs/detect/train
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/300      2.86G      3.864      3.795      3.232         85        640: 100%|██████████| 307/307 [00:39<00:00,  7.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:11<00:00,  4.20it/s]
#                    all       1515      14302      0.857     0.0822     0.0767     0.0374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/300      3.65G      2.317      2.508      2.102         23        640: 100%|██████████| 307/307 [00:36<00:00,  8.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.64it/s]
#                    all       1515      14302      0.927      0.126      0.147     0.0882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/300      3.66G      1.964       2.12      1.763         72        640: 100%|██████████| 307/307 [00:35<00:00,  8.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:11<00:00,  4.32it/s]
#                    all       1515      14302      0.934       0.15      0.179      0.104
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/300      3.67G       1.76       1.85       1.58         40        640: 100%|██████████| 307/307 [00:35<00:00,  8.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:09<00:00,  5.07it/s]
#                    all       1515      14302      0.755      0.192      0.207       0.12
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/300      3.68G      1.651      1.695      1.512         82        640: 100%|██████████| 307/307 [00:35<00:00,  8.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.38it/s]
#                    all       1515      14302      0.302      0.277      0.268      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/300      3.69G      1.564      1.557      1.457         36        640: 100%|██████████| 307/307 [00:35<00:00,  8.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.37it/s]
#                    all       1515      14302      0.446      0.337      0.349       0.21
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/300       3.7G      1.517      1.462      1.417        118        640: 100%|██████████| 307/307 [00:35<00:00,  8.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.69it/s]
#                    all       1515      14302       0.48      0.344      0.378      0.229
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/300      3.71G      1.458      1.365      1.384         38        640: 100%|██████████| 307/307 [00:35<00:00,  8.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.68it/s]
#                    all       1515      14302      0.478      0.408      0.408      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/300      3.71G      1.437      1.316      1.365        101        640: 100%|██████████| 307/307 [00:35<00:00,  8.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.68it/s]
#                    all       1515      14302      0.515      0.453      0.428      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/300      3.73G       1.39      1.261      1.333         35        640: 100%|██████████| 307/307 [00:35<00:00,  8.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.62it/s]
#                    all       1515      14302      0.491      0.423      0.421      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/300      3.74G      1.371      1.228      1.322        119        640: 100%|██████████| 307/307 [00:35<00:00,  8.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.57it/s]
#                    all       1515      14302      0.555       0.47      0.484      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/300      3.75G      1.355      1.198      1.311         93        640: 100%|██████████| 307/307 [00:35<00:00,  8.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.75it/s]
#                    all       1515      14302      0.579      0.471      0.491      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/300      3.75G      1.323      1.156      1.293         64        640: 100%|██████████| 307/307 [00:35<00:00,  8.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.81it/s]
#                    all       1515      14302       0.58      0.474      0.519      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/300      3.77G      1.315      1.131      1.285        110        640: 100%|██████████| 307/307 [00:35<00:00,  8.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.78it/s]
#                    all       1515      14302      0.593        0.5      0.528      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/300      3.78G      1.293      1.112      1.277         62        640: 100%|██████████| 307/307 [00:35<00:00,  8.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.80it/s]
#                    all       1515      14302      0.611      0.494      0.537      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/300      3.79G      1.268      1.079      1.252         74        640: 100%|██████████| 307/307 [00:35<00:00,  8.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.88it/s]
#                    all       1515      14302      0.631      0.521      0.563      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/300      3.79G      1.263      1.074      1.248         33        640: 100%|██████████| 307/307 [00:35<00:00,  8.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.76it/s]
#                    all       1515      14302      0.622      0.513      0.551      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/300      3.81G      1.244      1.055      1.242         45        640: 100%|██████████| 307/307 [00:35<00:00,  8.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.81it/s]
#                    all       1515      14302       0.65      0.547      0.583      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/300      3.82G       1.24      1.039      1.242         98        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.87it/s]
#                    all       1515      14302      0.664      0.547      0.597      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/300      3.83G      1.221      1.019       1.23         65        640: 100%|██████████| 307/307 [00:36<00:00,  8.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.70it/s]
#                    all       1515      14302      0.668      0.557      0.605      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/300      3.83G      1.217      1.009      1.228         83        640: 100%|██████████| 307/307 [00:36<00:00,  8.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.78it/s]
#                    all       1515      14302      0.658      0.566      0.614      0.401
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/300      3.85G      1.212     0.9966      1.218         41        640: 100%|██████████| 307/307 [00:36<00:00,  8.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.80it/s]
#                    all       1515      14302      0.702       0.57      0.631      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/300      3.86G      1.204      0.996      1.222         63        640: 100%|██████████| 307/307 [00:36<00:00,  8.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.82it/s]
#                    all       1515      14302      0.697      0.576      0.639      0.418
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/300      4.24G      1.185     0.9761      1.206         57        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.84it/s]
#                    all       1515      14302      0.682      0.583       0.64      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/300      4.24G      1.171     0.9599        1.2         43        640: 100%|██████████| 307/307 [00:36<00:00,  8.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.82it/s]
#                    all       1515      14302      0.699      0.575      0.642       0.42
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/300      4.26G      1.173      0.952      1.196        104        640: 100%|██████████| 307/307 [00:36<00:00,  8.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.76it/s]
#                    all       1515      14302      0.669      0.584      0.636      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/300      4.27G      1.174     0.9576      1.195         31        640: 100%|██████████| 307/307 [00:35<00:00,  8.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.80it/s]
#                    all       1515      14302      0.697      0.603      0.661      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/300      4.28G      1.168     0.9494      1.194         59        640: 100%|██████████| 307/307 [00:36<00:00,  8.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.77it/s]
#                    all       1515      14302      0.685      0.587       0.65      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/300      4.29G      1.153     0.9309      1.184         49        640: 100%|██████████| 307/307 [00:36<00:00,  8.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.85it/s]
#                    all       1515      14302       0.69      0.607      0.666      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/300       4.3G       1.15     0.9265      1.181         58        640: 100%|██████████| 307/307 [00:36<00:00,  8.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.82it/s]
#                    all       1515      14302      0.721      0.588       0.67      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/300      4.31G      1.136     0.9082       1.17         49        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.83it/s]
#                    all       1515      14302      0.708       0.62      0.678      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/300      4.32G       1.14      0.908      1.172         27        640: 100%|██████████| 307/307 [00:36<00:00,  8.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.81it/s]
#                    all       1515      14302      0.713      0.606      0.671      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/300      4.32G      1.127     0.9064      1.168         50        640: 100%|██████████| 307/307 [00:36<00:00,  8.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.76it/s]
#                    all       1515      14302      0.708      0.624      0.691      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/300      4.34G      1.124     0.8946      1.162         67        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.82it/s]
#                    all       1515      14302      0.731      0.613       0.69      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/300      4.35G      1.122      0.895      1.165         78        640: 100%|██████████| 307/307 [00:35<00:00,  8.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.88it/s]
#                    all       1515      14302      0.724      0.612      0.688      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/300      4.36G       1.11     0.8769      1.154         65        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.88it/s]
#                    all       1515      14302      0.751       0.62        0.7      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/300      4.36G      1.117     0.8881      1.159         44        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.81it/s]
#                    all       1515      14302      0.721      0.623      0.695      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/300      4.38G      1.112     0.8766      1.158         68        640: 100%|██████████| 307/307 [00:35<00:00,  8.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.89it/s]
#                    all       1515      14302      0.749      0.625      0.704      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/300      4.39G      1.107      0.885      1.158         45        640: 100%|██████████| 307/307 [00:35<00:00,  8.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.85it/s]
#                    all       1515      14302      0.746      0.639      0.712      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/300       4.4G      1.096     0.8555      1.145         81        640: 100%|██████████| 307/307 [00:35<00:00,  8.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.85it/s]
#                    all       1515      14302      0.744      0.631      0.704      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/300       4.4G      1.093     0.8533      1.141         74        640: 100%|██████████| 307/307 [00:36<00:00,  8.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.91it/s]
#                    all       1515      14302      0.748      0.631      0.711      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/300      4.42G       1.09     0.8605      1.143         40        640: 100%|██████████| 307/307 [00:36<00:00,  8.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.88it/s]
#                    all       1515      14302      0.761      0.637       0.72      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/300      4.43G      1.079     0.8469      1.138         87        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.81it/s]
#                    all       1515      14302      0.753       0.63      0.712      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/300      4.44G      1.086     0.8429      1.139         50        640: 100%|██████████| 307/307 [00:36<00:00,  8.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.88it/s]
#                    all       1515      14302      0.736      0.638      0.712        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/300      4.44G      1.067     0.8288      1.131        111        640: 100%|██████████| 307/307 [00:36<00:00,  8.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.89it/s]
#                    all       1515      14302      0.753      0.648      0.722      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/300      4.46G      1.076     0.8389      1.133         28        640: 100%|██████████| 307/307 [00:36<00:00,  8.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.88it/s]
#                    all       1515      14302      0.773      0.628      0.722      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/300      4.47G      1.074      0.826      1.129         67        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.87it/s]
#                    all       1515      14302       0.75      0.654      0.729      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/300      4.48G      1.068     0.8287      1.123         75        640: 100%|██████████| 307/307 [00:36<00:00,  8.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.80it/s]
#                    all       1515      14302      0.746      0.657      0.731      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/300      4.48G      1.066     0.8256      1.126         74        640: 100%|██████████| 307/307 [00:36<00:00,  8.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.89it/s]
#                    all       1515      14302      0.762      0.639      0.722      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/300       4.5G      1.071     0.8317      1.126         60        640: 100%|██████████| 307/307 [00:35<00:00,  8.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.79it/s]
#                    all       1515      14302      0.772      0.642      0.732      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/300      4.51G      1.063     0.8195      1.116         47        640: 100%|██████████| 307/307 [00:36<00:00,  8.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.92it/s]
#                    all       1515      14302      0.762      0.641      0.722      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/300      4.52G       1.05     0.8191      1.124         97        640: 100%|██████████| 307/307 [00:36<00:00,  8.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.85it/s]
#                    all       1515      14302      0.756      0.647      0.733       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/300      4.52G      1.054     0.8218      1.125         69        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.87it/s]
#                    all       1515      14302      0.743       0.68      0.742      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/300      4.54G       1.05     0.8124      1.119         72        640: 100%|██████████| 307/307 [00:36<00:00,  8.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.85it/s]
#                    all       1515      14302      0.759      0.654      0.738      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/300      4.55G      1.047     0.8119      1.118        101        640: 100%|██████████| 307/307 [00:36<00:00,  8.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.87it/s]
#                    all       1515      14302       0.77      0.659      0.743       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/300      4.56G      1.049     0.8083      1.116         80        640: 100%|██████████| 307/307 [00:36<00:00,  8.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.82it/s]
#                    all       1515      14302      0.764      0.636      0.725      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/300      4.56G      1.052     0.8101      1.117         36        640: 100%|██████████| 307/307 [00:36<00:00,  8.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.90it/s]
#                    all       1515      14302      0.759      0.653      0.737      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/300      4.58G      1.046     0.7965      1.111         97        640: 100%|██████████| 307/307 [00:36<00:00,  8.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.88it/s]
#                    all       1515      14302      0.775      0.641      0.743      0.528
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/300      4.58G      1.043     0.8009       1.11         52        640: 100%|██████████| 307/307 [00:36<00:00,  8.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.93it/s]
#                    all       1515      14302      0.783      0.666      0.749      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/300       4.6G      1.031     0.7881      1.107         94        640: 100%|██████████| 307/307 [00:36<00:00,  8.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.93it/s]
#                    all       1515      14302      0.774      0.668      0.753      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/300       4.6G      1.033     0.7988       1.11         37        640: 100%|██████████| 307/307 [00:36<00:00,  8.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.90it/s]
#                    all       1515      14302      0.781      0.678      0.755      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/300      4.62G      1.027     0.7854      1.103         62        640: 100%|██████████| 307/307 [00:36<00:00,  8.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.91it/s]
#                    all       1515      14302       0.79      0.659      0.754      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/300      4.62G      1.031     0.7938      1.108         57        640: 100%|██████████| 307/307 [00:35<00:00,  8.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.94it/s]
#                    all       1515      14302      0.783      0.667      0.757      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/300      4.64G      1.025     0.7862      1.102        128        640: 100%|██████████| 307/307 [00:35<00:00,  8.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.87it/s]
#                    all       1515      14302      0.796      0.657      0.758      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/300      4.64G      1.019     0.7794      1.104         46        640: 100%|██████████| 307/307 [00:35<00:00,  8.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.89it/s]
#                    all       1515      14302      0.785      0.677      0.766      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/300      4.65G      1.017     0.7715      1.097         61        640: 100%|██████████| 307/307 [00:35<00:00,  8.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.88it/s]
#                    all       1515      14302      0.774      0.673      0.758      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/300      4.66G      1.027     0.7791      1.101         37        640: 100%|██████████| 307/307 [00:35<00:00,  8.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.81it/s]
#                    all       1515      14302      0.792      0.672      0.764      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/300      4.67G      1.019      0.785      1.101         25        640: 100%|██████████| 307/307 [00:35<00:00,  8.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.90it/s]
#                    all       1515      14302      0.784      0.682      0.767      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/300      4.68G      1.016     0.7667      1.095        125        640: 100%|██████████| 307/307 [00:36<00:00,  8.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.97it/s]
#                    all       1515      14302      0.779      0.678      0.767      0.553
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/300      4.69G      1.006     0.7633      1.092         62        640: 100%|██████████| 307/307 [00:35<00:00,  8.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.93it/s]
#                    all       1515      14302      0.801      0.666      0.766      0.554
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/300       4.7G      1.013     0.7651      1.091        110        640: 100%|██████████| 307/307 [00:35<00:00,  8.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.87it/s]
#                    all       1515      14302      0.788      0.663      0.761      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/300      4.71G      1.005     0.7654      1.091         55        640: 100%|██████████| 307/307 [00:35<00:00,  8.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.87it/s]
#                    all       1515      14302      0.784      0.687      0.773       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/300      4.72G      1.004     0.7664      1.094         17        640: 100%|██████████| 307/307 [00:35<00:00,  8.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.96it/s]
#                    all       1515      14302      0.801      0.682      0.773      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/300      4.73G      1.004     0.7592       1.09         63        640: 100%|██████████| 307/307 [00:36<00:00,  8.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.92it/s]
#                    all       1515      14302      0.799      0.679      0.769      0.559
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/300      4.74G      0.988     0.7485      1.082         46        640: 100%|██████████| 307/307 [00:35<00:00,  8.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.87it/s]
#                    all       1515      14302      0.783       0.69      0.769      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/300      4.75G     0.9947      0.754       1.08         43        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.89it/s]
#                    all       1515      14302      0.773      0.691       0.77      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/300      4.76G     0.9991      0.755      1.086         46        640: 100%|██████████| 307/307 [00:36<00:00,  8.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.92it/s]
#                    all       1515      14302       0.78      0.691       0.77      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/300      4.77G      0.997     0.7496      1.084         42        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.92it/s]
#                    all       1515      14302       0.78      0.695      0.775      0.565
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/300      4.78G     0.9985     0.7478      1.088         66        640: 100%|██████████| 307/307 [00:36<00:00,  8.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.87it/s]
#                    all       1515      14302      0.795      0.687      0.777      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/300      4.79G     0.9964     0.7541      1.084         42        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.95it/s]
#                    all       1515      14302      0.805      0.696      0.781       0.57
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/300      4.79G     0.9979     0.7471      1.088         59        640: 100%|██████████| 307/307 [00:35<00:00,  8.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.91it/s]
#                    all       1515      14302      0.795      0.698      0.782      0.571
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/300      4.81G     0.9806     0.7458      1.079         88        640: 100%|██████████| 307/307 [00:36<00:00,  8.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.90it/s]
#                    all       1515      14302      0.804      0.689      0.785       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/300      4.82G     0.9889     0.7456      1.078         53        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.94it/s]
#                    all       1515      14302      0.806      0.687      0.782      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/300      4.83G     0.9935     0.7451       1.08         46        640: 100%|██████████| 307/307 [00:36<00:00,  8.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.86it/s]
#                    all       1515      14302      0.811      0.687      0.787      0.572
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/300      4.83G     0.9866     0.7412      1.077         52        640: 100%|██████████| 307/307 [00:36<00:00,  8.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.89it/s]
#                    all       1515      14302      0.786      0.697      0.779      0.567
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/300      4.85G      0.983     0.7376      1.077         51        640: 100%|██████████| 307/307 [00:36<00:00,  8.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.96it/s]
#                    all       1515      14302      0.809      0.693      0.786      0.573
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/300      4.86G     0.9809     0.7341      1.075         58        640: 100%|██████████| 307/307 [00:35<00:00,  8.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.94it/s]
#                    all       1515      14302      0.795      0.695      0.783      0.571
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/300      4.87G     0.9853     0.7323      1.077         60        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.94it/s]
#                    all       1515      14302      0.804      0.704       0.79      0.578
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/300      4.88G     0.9753     0.7262      1.072         96        640: 100%|██████████| 307/307 [00:35<00:00,  8.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.91it/s]
#                    all       1515      14302      0.799      0.697      0.783      0.572
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/300      4.89G     0.9782     0.7325      1.077         51        640: 100%|██████████| 307/307 [00:35<00:00,  8.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.95it/s]
#                    all       1515      14302      0.811      0.697      0.788      0.576
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/300       4.9G     0.9819     0.7334      1.077         36        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.95it/s]
#                    all       1515      14302      0.826      0.693      0.791      0.579
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/300      4.91G     0.9865     0.7365      1.079         63        640: 100%|██████████| 307/307 [00:35<00:00,  8.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.91it/s]
#                    all       1515      14302      0.806      0.704       0.79      0.579
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/300      4.91G     0.9727     0.7231      1.073         97        640: 100%|██████████| 307/307 [00:35<00:00,  8.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.89it/s]
#                    all       1515      14302      0.808      0.699      0.792       0.58
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/300      4.93G     0.9691     0.7216      1.065         65        640: 100%|██████████| 307/307 [00:36<00:00,  8.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.96it/s]
#                    all       1515      14302      0.828      0.692      0.792       0.58
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/300      4.94G     0.9817     0.7348      1.072         68        640: 100%|██████████| 307/307 [00:35<00:00,  8.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:08<00:00,  5.90it/s]
#                    all       1515      14302      0.833      0.681      0.791       0.58
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# ...
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[   0.066193,    0.066193,      0.1003, ...,           1,           1,           1],
#        [     0.1801,      0.1801,     0.24321, ...,           1,           1,           1],
#        [   0.040304,    0.040304,     0.05839, ...,           1,           1,           1],
#        [   0.094704,    0.094704,     0.14023, ...,           1,           1,           1]]), 'Confidence', 'Precision'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[    0.94877,     0.94877,     0.94212, ...,           0,           0,           0],
#        [    0.97493,     0.97493,     0.97256, ...,           0,           0,           0],
#        [    0.94375,     0.94375,     0.91875, ...,           0,           0,           0],
#        [    0.97416,     0.97416,     0.96761, ...,           0,           0,           0]]), 'Confidence', 'Recall']]
# fitness: np.float64(0.6380962304863597)
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([     0.5969,     0.74642,      0.4331,     0.69569])
# names: {0: 'echinus', 1: 'holothurian', 2: 'scallop', 3: 'starfish'}
# plot: True
# results_dict: {'metrics/precision(B)': np.float64(0.8260785736150275), 'metrics/recall(B)': np.float64(0.7312161207251276), 'metrics/mAP50(B)': np.float64(0.8187085706915699), 'metrics/mAP50-95(B)': np.float64(0.6180281926857807), 'fitness': np.float64(0.6380962304863597)}
# save_dir: PosixPath('/content/HaYOLO/runs/detect/train')
# speed: {'preprocess': 0.17157722508476966, 'inference': 1.4463725438923671, 'loss': 0.0003854435652539767, 'postprocess': 1.3444844858115097}
# task: 'detect'

# %% [markdown]
# # Evaluate

# %% [markdown]
# ## Assess GFLOPs, Parameters, and Size

# %%
best_weights = '/content/HaYOLO/runs/detect/train/weights/best.pt'
best_model   = YOLO(best_weights)
print("----- Detailed Model Summary (verbose) -----")
best_model.info(verbose=True)
size_bytes = os.path.getsize(best_weights)
size_mb    = size_bytes / (1024 ** 2)
print(f"Checkpoint file size: {size_mb:.2f} MB")
# Out:
# ----- Detailed Model Summary (verbose) -----
# YOLOv11n_C2PSA summary: 181 layers, 2,590,620 parameters, 0 gradients, 6.4 GFLOPs
# Checkpoint file size: 5.25 MB

# %%
from thop import profile
import torch
best_model.model.to('cuda')
input = torch.randn(1, 3, 640, 640).to('cuda')
macs, params = profile(best_model.model, inputs=(input, ))
gflops = macs / 1e9
print(f"GFLOPs: {gflops:.2f}")
# Out:
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register count_upsample() for <class 'torch.nn.modules.upsampling.Upsample'>.
# GFLOPs: 3.22

# %%
# Save model summary
with open("model_summary.txt", "w") as f:
    f.write("----- Model Summary -----\n")
    f.write(f"Parameters: {params:,}\n")
    f.write(f"Checkpoint file size: {size_mb:.2f} MB\n")
    f.write(f"GFLOPs: {gflops:.2f}\n")

# %% [markdown]
# ## Evaluate on Test Set

# %%
test_results = best_model.val(
    data=data_yaml_path,
    split='test',
    batch=16,
    imgsz=640,
    save_json=True,
    save_txt=True,
    plots=True,
    verbose=True
)
# Out:
# Ultralytics 8.3.143 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# YOLOv11n_C2PSA summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1993.8±844.0 MB/s, size: 154.4 KB)
# val: Scanning /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/labels... 763 images, 2 backgrounds, 1 corrupt: 100%|██████████| 763/763 [00:00<00:00, 1479.70it/s]
# val: /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3783.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0002]
# val: New cache created: /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 48/48 [00:37<00:00,  1.30it/s]
#                    all        762       7195      0.843      0.769      0.854       0.65
#                echinus        346        810      0.821      0.747       0.84      0.595
#            holothurian        669       4726      0.905      0.846      0.933      0.747
#                scallop         62        243      0.749      0.652       0.73      0.538
#               starfish        473       1416      0.898       0.83      0.914      0.719
# Speed: 0.4ms preprocess, 2.2ms inference, 0.0ms loss, 2.2ms postprocess per image
# Saving /content/HaYOLO/runs/detect/val/predictions.json...
# Results saved to /content/HaYOLO/runs/detect/val

# %%
precision = test_results.box.mp
recall = test_results.box.mr
f1_score = 2 * (precision * recall) / (precision + recall + 1e-6)

# %%
# Print key metrics
print(f"Test mAP50: {test_results.box.map50:.4f}")
print(f"Test mAP50-95: {test_results.box.map:.4f}")
print(f"Test mAP75: {test_results.box.map75:.4f}")
print(f"Test Precision: {test_results.box.mp:.4f}")
print(f"Test Recall: {test_results.box.mr:.4f}")
print(f"Test F1 Score: {f1_score:.4f}")
# Out:
# Test mAP50: 0.8544
# Test mAP50-95: 0.6496
# Test mAP75: 0.7387
# Test Precision: 0.8434
# Test Recall: 0.7687
# Test F1 Score: 0.8043

# %%
# Save test metrics
with open("test_metrics.txt", "w") as f:
    f.write("----- Test Metrics -----\n")
    f.write(f"Test mAP50: {test_results.box.map50:.4f}\n")
    f.write(f"Test mAP75: {test_results.box.map75:.4f}\n")
    f.write(f"Test mAP50-95: {test_results.box.map:.4f}\n")
    f.write(f"Test Precision: {test_results.box.mp:.4f}\n")
    f.write(f"Test Recall: {test_results.box.mr:.4f}\n")
    f.write(f"Test F1 Score: {f1_score:.4f}\n")

# %% [markdown]
# ## Export Confusion Matrices as CSV

# %%
cm_test = test_results.confusion_matrix.matrix
np.savetxt("cm_test.csv", cm_test, delimiter=",", fmt="%.0f")

# %% [markdown]
# ## Export Per-Class Metrics

# %%
# ---- Export Per-Class Metrics ----
num_classes = len(test_results.box.p)
per_class_metrics = pd.DataFrame({
    "Class ID": np.arange(num_classes),
    "Class Name": [best_model.names[i] for i in range(num_classes)],
    "Precision": test_results.box.p,
    "Recall": test_results.box.r,
    "F1 Score": test_results.box.f1,
    "AP50": test_results.box.ap50,
    "AP50-95": test_results.box.ap
})
per_class_metrics.to_csv("per_class_metrics.csv", index=False)
print("✅ Exported per_class_metrics.csv")
# Out:
# ✅ Exported per_class_metrics.csv

# %% [markdown]
# ## Plot LR Progression Against Loss & mAP

# %%
results_csv = Path('/content/HaYOLO/runs/detect/train/results.csv')
df = pd.read_csv(results_csv)
print(df.columns)
# Out:
# Index(['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss',
#        'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)',
#        'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss',
#        'lr/pg0', 'lr/pg1', 'lr/pg2'],
#       dtype='object')

# %%
df
# Out:
#      epoch        time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0        1     51.1466         3.86431         3.79531         3.23238
# 1        2     96.3848         2.31712         2.50763         2.10212
# 2        3    143.8030         1.96443         2.12008         1.76316
# 3        4    189.4430         1.75957         1.85038         1.57955
# 4        5    234.3540         1.65128         1.69548         1.51217
# ..     ...         ...             ...             ...             ...
# 295    296  13100.9000         0.76568         0.48717         0.96688
# 296    297  13144.0000         0.76059         0.48685         0.96315
# 297    298  13187.1000         0.76378         0.49097         0.96631
# 298    299  13230.2000         0.75687         0.48336         0.96274
# 299    300  13273.3000         0.75827         0.48379         0.96457
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                 0.85679            0.08216           0.07669
# 1                 0.92726            0.12594           0.14747
# 2                 0.93372            0.15040           0.17881
# 3                 0.75451            0.19197           0.20726
# 4                 0.30200            0.27749           0.26772
# ..                    ...                ...               ...
# 295               0.82439            0.73213           0.81893
# 296               0.82775            0.73123           0.81903
# 297               0.82629            0.73146           0.81895
# 298               0.82856            0.73016           0.81877
# 299               0.82718            0.73005           0.81865
#
#      metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0                0.03744       2.40761       3.02820       2.40980  0.070098
# 1                0.08818       1.89488       1.97093       1.88564  0.040078
# 2                0.10377       1.65605       1.84550       1.63861  0.010038
# 3                0.11962       1.64143       1.64693       1.59703  0.009910
# 4                0.15579       1.46299       1.49418       1.47192  0.009880
# ..                   ...           ...           ...           ...       ...
# 295              0.61796       0.79252       0.53746       0.99466  0.001150
# 296              0.61826       0.79254       0.53746       0.99471  0.001120
# 297              0.61808       0.79250       0.53757       0.99466  0.001090
# 298              0.61829       0.79259       0.53768       0.99466  0.001060
# 299              0.61804       0.79248       0.53776       0.99456  0.001030
#
#        lr/pg1    lr/pg2
# 0    0.003322  0.003322
# 1    0.006636  0.006636
# 2    0.009929  0.009929
# 3    0.009910  0.009910
# 4    0.009880  0.009880
# ..        ...       ...
# 295  0.001150  0.001150
# 296  0.001120  0.001120
# 297  0.001090  0.001090
# 298  0.001060  0.001060
# 299  0.001030  0.001030
#
# [300 rows x 15 columns]

# %%
# ===== Plot 1: Train Loss, mAP, LR =====
fig, ax1 = plt.subplots(figsize=(8, 5))

# Plot training losses
ax1.plot(df.index, df['train/box_loss'], label='Train Box loss')
ax1.plot(df.index, df['train/cls_loss'], label='Train Cls loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Train Loss')
ax1.legend(loc='upper left')

# Twin axis for mAP and LR
ax2 = ax1.twinx()
ax2.plot(df.index, df['metrics/mAP50(B)'], '--', label='mAP50')
ax2.plot(df.index, df['metrics/mAP50-95(B)'], '--', label='mAP50-95')
ax2.plot(df.index, df['lr/pg0'], ':', label='LR')
ax2.set_ylabel('mAP / LR')
ax2.legend(loc='upper right')

plt.title('Learning Rate vs. Train Loss and mAP')
plt.tight_layout()
plt.savefig('train_loss_vs_map_lr.png', dpi=300)
plt.show()  # Show plot 1

# %%
# ===== Plot 2: Validation Losses =====
fig2, ax = plt.subplots(figsize=(8, 5))
ax.plot(df.index, df['val/box_loss'], label='Val Box loss')
ax.plot(df.index, df['val/cls_loss'], label='Val Cls loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Validation Loss')
ax.legend()
plt.title('Validation Box and Cls Loss')
plt.tight_layout()
plt.savefig('val_loss.png', dpi=300)
plt.show()  # Show plot 2

# %% [markdown]
# ## Visualize Sample Object Detection

# %%
test_images_dir = pathlib.Path(test_folder)
test_labels_dir = test_images_dir.parent / 'labels'

all_test_images = list(test_images_dir.glob('*.jpg')) + list(test_images_dir.glob('*.png'))
if not all_test_images:
    raise RuntimeError(f"No images found in {test_images_dir}")

N = 5
sample_images = random.sample(all_test_images, k=min(N, len(all_test_images)))

for img_path in sample_images:
    img     = cv2.imread(str(img_path))
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    h, w, _ = img.shape

    results = best_model.predict(source=str(img_path), conf=0.25)
    preds   = results[0].boxes  # .boxes.xyxy, .boxes.cls, .boxes.conf

    label_file = test_labels_dir / f"{img_path.stem}.txt"
    gt_boxes = []
    if label_file.exists():
        with open(label_file, 'r') as f:
            for line in f:
                toks = line.split()
                if len(toks) < 5:
                    continue
                cls_id   = int(float(toks[0]))
                x_center = float(toks[1])
                y_center = float(toks[2])
                bw       = float(toks[3])
                bh       = float(toks[4])
                x_min = (x_center - bw / 2) * w
                y_min = (y_center - bh / 2) * h
                x_max = (x_center + bw / 2) * w
                y_max = (y_center + bh / 2) * h
                gt_boxes.append((int(x_min), int(y_min), int(x_max), int(y_max), cls_id))
    else:
        print(f"⚠️ Warning: No label file for {img_path.name}")

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    ax_gt, ax_pred = axes[0], axes[1]

    ax_gt.imshow(img_rgb)
    ax_gt.set_title("Ground Truth (red)")
    ax_gt.axis('off')
    for (xmin, ymin, xmax, ymax, cls_id) in gt_boxes:
        rect = patches.Rectangle(
            (xmin, ymin),
            xmax - xmin,
            ymax - ymin,
            linewidth=2,
            edgecolor='red',
            facecolor='none',
            linestyle='-'
        )
        ax_gt.add_patch(rect)
        ax_gt.text(
            xmin,
            ymin - 5,
            f"{best_model.names[cls_id]}",
            color='red',
            fontsize=10
        )

    ax_pred.imshow(img_rgb)
    ax_pred.set_title("Predictions (blue)")
    ax_pred.axis('off')
    for box in preds:
        x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
        cls_id = int(box.cls.cpu().numpy()[0])
        conf   = float(box.conf.cpu().numpy()[0])
        rect = patches.Rectangle(
            (x1, y1),
            x2 - x1,
            y2 - y1,
            linewidth=2,
            edgecolor='blue',
            facecolor='none',
            linestyle='--'
        )
        ax_pred.add_patch(rect)
        ax_pred.text(
            x1,
            y1 - 5,
            f"{best_model.names[cls_id]} {conf:.2f}",
            color='blue',
            fontsize=10
        )

    plt.suptitle(f"Image: {img_path.name}", fontsize=14)
    plt.tight_layout()
    plt.show()
# Out:
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4352.jpg: 640x640 2 echinuss, 10 holothurians, 2 starfishs, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4908.jpg: 640x640 1 echinus, 10.6ms
# Speed: 3.3ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/995.jpg: 640x640 49 holothurians, 2 starfishs, 11.7ms
# Speed: 2.8ms preprocess, 11.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1632.jpg: 640x640 1 echinus, 6 holothurians, 8 starfishs, 11.4ms
# Speed: 2.7ms preprocess, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3219.jpg: 640x640 2 holothurians, 11.6ms
# Speed: 2.7ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)

# %%
output_dir = Path("sample_visualizations")
output_dir.mkdir(parents=True, exist_ok=True)

N = 5
sample_images = random.sample(all_test_images, k=min(N, len(all_test_images)))

for img_path in sample_images:
    img     = cv2.imread(str(img_path))
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    h, w, _ = img.shape

    results = best_model.predict(source=str(img_path), conf=0.25)
    preds   = results[0].boxes

    label_file = test_labels_dir / f"{img_path.stem}.txt"
    gt_boxes = []
    if label_file.exists():
        with open(label_file, 'r') as f:
            for line in f:
                toks = line.split()
                if len(toks) < 5:
                    continue
                cls_id   = int(float(toks[0]))
                x_center = float(toks[1])
                y_center = float(toks[2])
                bw       = float(toks[3])
                bh       = float(toks[4])
                x_min = (x_center - bw / 2) * w
                y_min = (y_center - bh / 2) * h
                x_max = (x_center + bw / 2) * w
                y_max = (y_center + bh / 2) * h
                gt_boxes.append((int(x_min), int(y_min), int(x_max), int(y_max), cls_id))
    else:
        print(f"⚠️ Warning: No label file for {img_path.name}")

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    ax_gt, ax_pred = axes[0], axes[1]

    ax_gt.imshow(img_rgb)
    ax_gt.set_title("Ground Truth (red)")
    ax_gt.axis('off')
    for (xmin, ymin, xmax, ymax, cls_id) in gt_boxes:
        rect = patches.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                 linewidth=2, edgecolor='red', facecolor='none')
        ax_gt.add_patch(rect)
        ax_gt.text(xmin, ymin - 5, f"{best_model.names[cls_id]}", color='red', fontsize=10)

    ax_pred.imshow(img_rgb)
    ax_pred.set_title("Predictions (blue)")
    ax_pred.axis('off')
    for box in preds:
        x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
        cls_id = int(box.cls.cpu().numpy()[0])
        conf   = float(box.conf.cpu().numpy()[0])
        rect = patches.Rectangle((x1, y1), x2 - x1, y2 - y1,
                                 linewidth=2, edgecolor='blue', facecolor='none', linestyle='--')
        ax_pred.add_patch(rect)
        ax_pred.text(x1, y1 - 5, f"{best_model.names[cls_id]} {conf:.2f}", color='blue', fontsize=10)

    plt.suptitle(f"Image: {img_path.name}", fontsize=14)
    plt.tight_layout()

    # ✅ Save the figure
    output_path = output_dir / f"{img_path.stem}_gt_vs_pred.png"
    plt.savefig(output_path, dpi=300)
    plt.show()
# Out:
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/171.jpg: 640x640 1 holothurian, 11.1ms
# Speed: 2.3ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6549.jpg: 640x640 1 echinus, 24 holothurians, 4 starfishs, 11.7ms
# Speed: 3.8ms preprocess, 11.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2237.jpg: 640x640 3 echinuss, 4 holothurians, 1 starfish, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/772.jpg: 640x640 2 holothurians, 13.3ms
# Speed: 3.9ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4900.jpg: 640x640 1 echinus, 1 starfish, 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# ## Export Prediction Results as CSV

# %%
# ---- Export Prediction Results ----
prediction_data = []
for img_path in all_test_images:
    results = best_model.predict(source=str(img_path), conf=0.25)
    preds = results[0].boxes
    for box in preds:
        x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
        cls_id = int(box.cls.cpu().numpy()[0])
        conf = float(box.conf.cpu().numpy()[0])
        prediction_data.append({
            "Image": img_path.name,
            "Class ID": cls_id,
            "Class Name": best_model.names[cls_id],
            "Confidence": conf,
            "X1": x1,
            "Y1": y1,
            "X2": x2,
            "Y2": y2
        })
df_preds = pd.DataFrame(prediction_data)
df_preds.to_csv("prediction_results.csv", index=False)
print("✅ Exported prediction_results.csv")
# Out:
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2179.jpg: 640x640 2 echinuss, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4456.jpg: 640x640 3 echinuss, 1 starfish, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6591.jpg: 640x640 7 holothurians, 1 starfish, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2126.jpg: 640x640 7 holothurians, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/268.jpg: 640x640 12 holothurians, 1 starfish, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3151.jpg: 640x640 1 echinus, 13 holothurians, 10 starfishs, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1973.jpg: 640x640 4 holothurians, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/104.jpg: 640x640 57 holothurians, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5018.jpg: 640x640 4 echinuss, 2 holothurians, 3 starfishs, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1635.jpg: 640x640 5 holothurians, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3256.jpg: 640x640 3 echinuss, 10 holothurians, 1 starfish, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3100.jpg: 640x640 14 holothurians, 11 starfishs, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1925.jpg: 640x640 2 echinuss, 9 holothurians, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1546.jpg: 640x640 1 holothurian, 2 starfishs, 10.3ms
# Speed: 1.7ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2285.jpg: 640x640 10 holothurians, 4 starfishs, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5014.jpg: 640x640 32 holothurians, 4 starfishs, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4466.jpg: 640x640 4 echinuss, 8 holothurians, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4330.jpg: 640x640 9 holothurians, 2 starfishs, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5126.jpg: 640x640 4 starfishs, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3031.jpg: 640x640 11 holothurians, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1111.jpg: 640x640 4 echinuss, 2 starfishs, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/515.jpg: 640x640 1 echinus, 14 holothurians, 1 starfish, 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3667.jpg: 640x640 7 holothurians, 10.9ms
# Speed: 1.9ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/62.jpg: 640x640 23 holothurians, 7 starfishs, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/283.jpg: 640x640 1 echinus, 7 holothurians, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4915.jpg: 640x640 8 holothurians, 1 starfish, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1828.jpg: 640x640 2 holothurians, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5687.jpg: 640x640 16 holothurians, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4186.jpg: 640x640 2 echinuss, 2 starfishs, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4502.jpg: 640x640 9 holothurians, 2 starfishs, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2041.jpg: 640x640 13 holothurians, 2 starfishs, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4991.jpg: 640x640 1 echinus, 2 holothurians, 11.9ms
# Speed: 1.8ms preprocess, 11.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5718.jpg: 640x640 1 echinus, 2 holothurians, 1 scallop, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/112.jpg: 640x640 2 holothurians, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1339.jpg: 640x640 2 echinuss, 2 holothurians, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1348.jpg: 640x640 5 holothurians, 1 starfish, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2074.jpg: 640x640 6 holothurians, 3 starfishs, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2986.jpg: 640x640 4 holothurians, 2 starfishs, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3233.jpg: 640x640 3 echinuss, 1 holothurian, 1 scallop, 4 starfishs, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/507.jpg: 640x640 7 holothurians, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2368.jpg: 640x640 2 echinuss, 1 holothurian, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1071.jpg: 640x640 2 holothurians, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2649.jpg: 640x640 11 holothurians, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2941.jpg: 640x640 1 echinus, 1 holothurian, 1 starfish, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2.jpg: 640x640 5 echinuss, 7 holothurians, 9 scallops, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4254.jpg: 640x640 2 echinuss, 6 holothurians, 1 starfish, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3452.jpg: 640x640 1 echinus, 4 holothurians, 1 starfish, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5676.jpg: 640x640 1 echinus, 3 holothurians, 1 scallop, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/794.jpg: 640x640 1 echinus, 2 holothurians, 1 starfish, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6280.jpg: 640x640 7 holothurians, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5320.jpg: 640x640 2 echinuss, 1 starfish, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/656.jpg: 640x640 1 echinus, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1555.jpg: 640x640 3 echinuss, 3 holothurians, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1429.jpg: 640x640 7 holothurians, 14 starfishs, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6637.jpg: 640x640 10 echinuss, 25 holothurians, 23 scallops, 3 starfishs, 11.0ms
# Speed: 1.7ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/405.jpg: 640x640 8 holothurians, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5275.jpg: 640x640 4 echinuss, 7 holothurians, 1 starfish, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4692.jpg: 640x640 4 holothurians, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/251.jpg: 640x640 1 echinus, 1 holothurian, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/225.jpg: 640x640 1 echinus, 15 holothurians, 2 starfishs, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4590.jpg: 640x640 14 holothurians, 8 starfishs, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5034.jpg: 640x640 9 holothurians, 3 starfishs, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5704.jpg: 640x640 1 echinus, 19 holothurians, 12 starfishs, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3184.jpg: 640x640 1 echinus, 3 holothurians, 1 starfish, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5149.jpg: 640x640 20 echinuss, 4 holothurians, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/312.jpg: 640x640 6 echinuss, 1 holothurian, 4 starfishs, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1021.jpg: 640x640 2 echinuss, 3 holothurians, 11.1ms
# Speed: 1.7ms preprocess, 11.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2552.jpg: 640x640 3 echinuss, 6 holothurians, 1 starfish, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1042.jpg: 640x640 4 holothurians, 1 starfish, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6671.jpg: 640x640 3 echinuss, 2 holothurians, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2987.jpg: 640x640 44 holothurians, 3 starfishs, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6011.jpg: 640x640 5 holothurians, 1 starfish, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/627.jpg: 640x640 9 holothurians, 1 starfish, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/998.jpg: 640x640 1 holothurian, 1 starfish, 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3037.jpg: 640x640 36 holothurians, 3 starfishs, 10.4ms
# Speed: 1.9ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1090.jpg: 640x640 3 echinuss, 10 holothurians, 6 starfishs, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4885.jpg: 640x640 1 echinus, 1 holothurian, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1514.jpg: 640x640 2 starfishs, 10.4ms
# Speed: 1.8ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1403.jpg: 640x640 2 echinuss, 8 holothurians, 2 starfishs, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6655.jpg: 640x640 2 holothurians, 1 starfish, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4251.jpg: 640x640 6 holothurians, 5 starfishs, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2161.jpg: 640x640 3 starfishs, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3063.jpg: 640x640 6 holothurians, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/883.jpg: 640x640 11 holothurians, 1 starfish, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5545.jpg: 640x640 1 holothurian, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2951.jpg: 640x640 14 holothurians, 2 starfishs, 11.7ms
# Speed: 1.8ms preprocess, 11.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1968.jpg: 640x640 1 echinus, 5 holothurians, 3 starfishs, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4778.jpg: 640x640 2 echinuss, 8 holothurians, 1 starfish, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6520.jpg: 640x640 7 holothurians, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4046.jpg: 640x640 6 holothurians, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/115.jpg: 640x640 2 holothurians, 1 starfish, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/676.jpg: 640x640 1 echinus, 21 holothurians, 30 starfishs, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6330.jpg: 640x640 4 echinuss, 4 holothurians, 2 starfishs, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1086.jpg: 640x640 4 holothurians, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/59.jpg: 640x640 4 echinuss, 4 holothurians, 9 starfishs, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6574.jpg: 640x640 2 echinuss, 17 holothurians, 4 starfishs, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1496.jpg: 640x640 1 echinus, 1 holothurian, 1 starfish, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4908.jpg: 640x640 1 echinus, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/548.jpg: 640x640 6 holothurians, 2 starfishs, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4000.jpg: 640x640 43 holothurians, 1 starfish, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1729.jpg: 640x640 9 holothurians, 1 scallop, 7 starfishs, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4900.jpg: 640x640 1 echinus, 1 starfish, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2276.jpg: 640x640 9 holothurians, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/521.jpg: 640x640 23 holothurians, 2 starfishs, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3022.jpg: 640x640 30 holothurians, 12 starfishs, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4732.jpg: 640x640 9 holothurians, 1 starfish, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4985.jpg: 640x640 1 echinus, 1 holothurian, 2 starfishs, 10.0ms
# Speed: 1.7ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3921.jpg: 640x640 9 holothurians, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4327.jpg: 640x640 4 holothurians, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5330.jpg: 640x640 6 holothurians, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6606.jpg: 640x640 2 holothurians, 4 starfishs, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3048.jpg: 640x640 32 holothurians, 3 starfishs, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6425.jpg: 640x640 1 holothurian, 1 starfish, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/514.jpg: 640x640 2 holothurians, 11.2ms
# Speed: 1.9ms preprocess, 11.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3065.jpg: 640x640 15 holothurians, 14.4ms
# Speed: 2.8ms preprocess, 14.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4624.jpg: 640x640 1 echinus, 1 holothurian, 1 starfish, 11.0ms
# Speed: 2.3ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3675.jpg: 640x640 17 scallops, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4265.jpg: 640x640 5 scallops, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2948.jpg: 640x640 1 echinus, 6 holothurians, 11.0ms
# Speed: 1.9ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4759.jpg: 640x640 3 echinuss, 4 holothurians, 1 scallop, 4 starfishs, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2631.jpg: 640x640 6 echinuss, 4 holothurians, 10 scallops, 3 starfishs, 10.7ms
# Speed: 1.9ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6229.jpg: 640x640 38 holothurians, 1 starfish, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2093.jpg: 640x640 5 echinuss, 1 holothurian, 4 starfishs, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2253.jpg: 640x640 1 echinus, 2 holothurians, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/631.jpg: 640x640 2 scallops, 11.8ms
# Speed: 1.8ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3136.jpg: 640x640 2 echinuss, 1 scallop, 10.8ms
# Speed: 1.9ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/324.jpg: 640x640 1 holothurian, 1 scallop, 1 starfish, 11.4ms
# Speed: 1.8ms preprocess, 11.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6228.jpg: 640x640 8 holothurians, 3 starfishs, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4373.jpg: 640x640 1 echinus, 11 holothurians, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5089.jpg: 640x640 6 echinuss, 1 holothurian, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3470.jpg: 640x640 2 echinuss, 7 holothurians, 1 starfish, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/106.jpg: 640x640 2 holothurians, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/490.jpg: 640x640 2 scallops, 3 starfishs, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6284.jpg: 640x640 3 holothurians, 1 starfish, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1033.jpg: 640x640 1 echinus, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2312.jpg: 640x640 2 starfishs, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4333.jpg: 640x640 10 holothurians, 11 starfishs, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3187.jpg: 640x640 56 holothurians, 6 starfishs, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/540.jpg: 640x640 11 holothurians, 4 starfishs, 11.4ms
# Speed: 1.9ms preprocess, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/949.jpg: 640x640 3 holothurians, 1 starfish, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/768.jpg: 640x640 4 echinuss, 3 holothurians, 2 starfishs, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/824.jpg: 640x640 3 echinuss, 1 starfish, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/474.jpg: 640x640 1 echinus, 4 holothurians, 3 starfishs, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4352.jpg: 640x640 2 echinuss, 10 holothurians, 2 starfishs, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2880.jpg: 640x640 7 holothurians, 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5387.jpg: 640x640 1 holothurian, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1219.jpg: 640x640 1 echinus, 17 holothurians, 4 starfishs, 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2868.jpg: 640x640 5 holothurians, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3977.jpg: 640x640 4 echinuss, 7 holothurians, 4 starfishs, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6283.jpg: 640x640 4 holothurians, 2 starfishs, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2237.jpg: 640x640 3 echinuss, 4 holothurians, 1 starfish, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6319.jpg: 640x640 1 echinus, 6 holothurians, 2 starfishs, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/341.jpg: 640x640 4 holothurians, 4 starfishs, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3958.jpg: 640x640 2 holothurians, 5 starfishs, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2088.jpg: 640x640 4 holothurians, 10.0ms
# Speed: 1.7ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6129.jpg: 640x640 15 echinuss, 25 holothurians, 12 scallops, 11.2ms
# Speed: 1.7ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5593.jpg: 640x640 12 scallops, 35 starfishs, 11.6ms
# Speed: 1.9ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3382.jpg: 640x640 1 echinus, 9 holothurians, 2 scallops, 6 starfishs, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/779.jpg: 640x640 2 echinuss, 4 holothurians, 1 starfish, 11.4ms
# Speed: 1.9ms preprocess, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/855.jpg: 640x640 4 holothurians, 1 scallop, 10.4ms
# Speed: 1.9ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/525.jpg: 640x640 7 holothurians, 10.4ms
# Speed: 1.9ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/403.jpg: 640x640 14 echinuss, 6 holothurians, 11 scallops, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1999.jpg: 640x640 2 holothurians, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1237.jpg: 640x640 4 holothurians, 10.4ms
# Speed: 1.9ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1927.jpg: 640x640 1 holothurian, 2 starfishs, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4947.jpg: 640x640 9 holothurians, 2 starfishs, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2398.jpg: 640x640 3 echinuss, 4 holothurians, 4 starfishs, 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6087.jpg: 640x640 1 holothurian, 2 starfishs, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2567.jpg: 640x640 1 echinus, 15 holothurians, 3 starfishs, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/12.jpg: 640x640 17 holothurians, 1 starfish, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6210.jpg: 640x640 5 holothurians, 10.7ms
# Speed: 1.9ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/999.jpg: 640x640 2 holothurians, 2 starfishs, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2031.jpg: 640x640 1 echinus, 3 holothurians, 3 starfishs, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2233.jpg: 640x640 3 echinuss, 7 holothurians, 3 starfishs, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1807.jpg: 640x640 15 holothurians, 2 starfishs, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1341.jpg: 640x640 3 holothurians, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3594.jpg: 640x640 15 holothurians, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4484.jpg: 640x640 3 holothurians, 10.7ms
# Speed: 1.9ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2805.jpg: 640x640 3 holothurians, 1 starfish, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/820.jpg: 640x640 4 holothurians, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1354.jpg: 640x640 2 echinuss, 2 holothurians, 2 starfishs, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5386.jpg: 640x640 14 holothurians, 6 starfishs, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5241.jpg: 640x640 1 echinus, 3 holothurians, 1 starfish, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3296.jpg: 640x640 1 holothurian, 10.4ms
# Speed: 1.9ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4476.jpg: 640x640 11 holothurians, 2 starfishs, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3833.jpg: 640x640 3 echinuss, 5 holothurians, 4 starfishs, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/771.jpg: 640x640 1 echinus, 1 holothurian, 1 starfish, 10.0ms
# Speed: 1.7ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6302.jpg: 640x640 1 echinus, 10 holothurians, 2 starfishs, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5562.jpg: 640x640 3 holothurians, 1 starfish, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2011.jpg: 640x640 1 echinus, 8 holothurians, 2 starfishs, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1028.jpg: 640x640 1 holothurian, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/819.jpg: 640x640 1 echinus, 3 holothurians, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1766.jpg: 640x640 1 echinus, 24 holothurians, 1 starfish, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1203.jpg: 640x640 3 echinuss, 11.3ms
# Speed: 1.8ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/614.jpg: 640x640 7 holothurians, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1746.jpg: 640x640 2 echinuss, 6 holothurians, 3 starfishs, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6038.jpg: 640x640 10 holothurians, 9.8ms
# Speed: 1.9ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3355.jpg: 640x640 8 holothurians, 2 starfishs, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1576.jpg: 640x640 7 holothurians, 1 starfish, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/411.jpg: 640x640 14 holothurians, 9.9ms
# ...
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6221.jpg: 640x640 7 holothurians, 1 starfish, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1776.jpg: 640x640 3 holothurians, 3 starfishs, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4257.jpg: 640x640 3 echinuss, 2 starfishs, 10.7ms
# Speed: 1.9ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4812.jpg: 640x640 1 echinus, 2 holothurians, 1 scallop, 3 starfishs, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/257.jpg: 640x640 7 holothurians, 1 starfish, 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4449.jpg: 640x640 1 echinus, 1 holothurian, 11.7ms
# Speed: 2.0ms preprocess, 11.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3421.jpg: 640x640 1 echinus, 3 holothurians, 2 starfishs, 10.5ms
# Speed: 2.8ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5892.jpg: 640x640 2 echinuss, 1 holothurian, 2 starfishs, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/685.jpg: 640x640 18 holothurians, 6 starfishs, 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3553.jpg: 640x640 2 holothurians, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/593.jpg: 640x640 1 holothurian, 2 starfishs, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5866.jpg: 640x640 2 holothurians, 2 starfishs, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/100.jpg: 640x640 3 echinuss, 9 holothurians, 3 starfishs, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5452.jpg: 640x640 1 echinus, 2 holothurians, 3 starfishs, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5449.jpg: 640x640 1 echinus, 6 holothurians, 12.8ms
# Speed: 2.0ms preprocess, 12.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3991.jpg: 640x640 1 echinus, 5 holothurians, 1 starfish, 10.2ms
# Speed: 2.3ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1064.jpg: 640x640 7 starfishs, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1533.jpg: 640x640 2 holothurians, 1 starfish, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/791.jpg: 640x640 3 holothurians, 1 scallop, 10.2ms
# Speed: 2.5ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1952.jpg: 640x640 15 holothurians, 16 starfishs, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5964.jpg: 640x640 21 holothurians, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6661.jpg: 640x640 7 holothurians, 10.4ms
# Speed: 1.9ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3436.jpg: 640x640 2 echinuss, 6 holothurians, 2 starfishs, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3862.jpg: 640x640 6 holothurians, 1 starfish, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6492.jpg: 640x640 4 holothurians, 2 starfishs, 10.1ms
# Speed: 2.6ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/171.jpg: 640x640 1 holothurian, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/972.jpg: 640x640 1 echinus, 7 holothurians, 2 starfishs, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6088.jpg: 640x640 8 echinuss, 11 holothurians, 2 scallops, 2 starfishs, 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/611.jpg: 640x640 7 holothurians, 3 starfishs, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/546.jpg: 640x640 4 holothurians, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2437.jpg: 640x640 1 holothurian, 9.9ms
# Speed: 1.9ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5333.jpg: 640x640 3 holothurians, 7 starfishs, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2659.jpg: 640x640 12 holothurians, 1 starfish, 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6306.jpg: 640x640 2 echinuss, 2 holothurians, 1 starfish, 10.3ms
# Speed: 2.7ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5524.jpg: 640x640 29 holothurians, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4451.jpg: 640x640 1 echinus, 6 holothurians, 3 starfishs, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4705.jpg: 640x640 14 echinuss, 18 holothurians, 8 scallops, 9.9ms
# Speed: 2.7ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3864.jpg: 640x640 2 echinuss, 7 holothurians, 1 starfish, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/397.jpg: 640x640 7 holothurians, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3385.jpg: 640x640 3 holothurians, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6086.jpg: 640x640 1 holothurian, 1 starfish, 11.0ms
# Speed: 1.7ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1872.jpg: 640x640 9 holothurians, 1 starfish, 10.4ms
# Speed: 1.9ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6509.jpg: 640x640 1 echinus, 2 scallops, 2 starfishs, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1097.jpg: 640x640 10 holothurians, 2 starfishs, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5362.jpg: 640x640 2 holothurians, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1878.jpg: 640x640 6 holothurians, 10.6ms
# Speed: 2.3ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4616.jpg: 640x640 4 holothurians, 2 starfishs, 10.2ms
# Speed: 2.7ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/18.jpg: 640x640 7 holothurians, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/1304.jpg: 640x640 1 echinus, 4 holothurians, 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4060.jpg: 640x640 2 echinuss, 2 holothurians, 3 starfishs, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/133.jpg: 640x640 1 echinus, 1 holothurian, 11.6ms
# Speed: 2.6ms preprocess, 11.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5536.jpg: 640x640 3 holothurians, 1 starfish, 10.4ms
# Speed: 2.0ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/552.jpg: 640x640 7 holothurians, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/4435.jpg: 640x640 2 echinuss, 8 holothurians, 6 starfishs, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/615.jpg: 640x640 4 echinuss, 10 holothurians, 3 starfishs, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6174.jpg: 640x640 2 echinuss, 2 holothurians, 10.0ms
# Speed: 1.7ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/150.jpg: 640x640 4 holothurians, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2614.jpg: 640x640 37 holothurians, 1 starfish, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/5685.jpg: 640x640 2 holothurians, 10.4ms
# Speed: 1.8ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/47.jpg: 640x640 4 echinuss, 7 holothurians, 5 scallops, 1 starfish, 12.2ms
# Speed: 2.1ms preprocess, 12.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2776.jpg: 640x640 6 holothurians, 3 starfishs, 12.0ms
# Speed: 1.8ms preprocess, 12.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/2111.jpg: 640x640 7 holothurians, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/497.jpg: 640x640 14 echinuss, 12 holothurians, 6 scallops, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/6428.jpg: 640x640 1 echinus, 2 holothurians, 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/3943.jpg: 640x640 7 holothurians, 2 starfishs, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DUO-dataset-2/content/DUO-dataset-github-enhanced-combined/test/images/349.jpg: 640x640 3 echinuss, 1 scallop, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Exported prediction_results.csv

# %% [markdown]
# ## Export Results as Zip

# %%
import datetime
from zipfile import ZipFile

# === Define dynamic export folder name based on YAML + timestamp ===
timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
clean_dataset = DATASET_TYPE.replace(" ", "_")
export_name = f"{model_name}_{clean_dataset}_{timestamp}"
export_dir = Path(export_name)
export_dir.mkdir(parents=True, exist_ok=True)

# === List of files to export ===
export_files = [
    "cm_test.csv",
    "per_class_metrics.csv",
    "train_loss_vs_map_lr.png",
    "val_loss.png",
    "model_summary.txt",
    "test_metrics.txt",
    "prediction_results.csv",
    yaml_path
]
# === Copy export files into the export folder ===
for file in export_files:
    src = Path(file)
    dst = export_dir / f"{src.stem}_{export_name}{src.suffix}"
    shutil.copy(src, dst)

# === Copy best.pt and last.pt directly to the root of export folder ===
weights_dir = Path("/content/HaYOLO/runs/detect/train/weights")
for weight_name in ["best.pt", "last.pt"]:
    weight_path = weights_dir / weight_name
    if weight_path.exists():
        weight_stem = Path(weight_name).stem
        weight_suffix = Path(weight_name).suffix
        renamed = f"{weight_stem}_{export_name}{weight_suffix}"
        shutil.copy(weight_path, export_dir / renamed)

# === Copy sample visualizations ===
sample_vis_dir = Path("sample_visualizations")
sample_vis_export = export_dir / f"sample_visualizations_{export_name}"
shutil.copytree(sample_vis_dir, sample_vis_export)

# === Copy HaYOLO runs/detect directory ===
detect_src = Path("/content/HaYOLO/runs/detect")
detect_dst = export_dir / f"detect_outputs_{export_name}"
shutil.copytree(detect_src, detect_dst)

# === Zip the export directory ===
zip_filename = f"{export_name}.zip"
shutil.make_archive(base_name=export_name, format='zip', root_dir=export_dir)
print(f"✅ Zipped everything into {zip_filename}")
# Out:
# ✅ Zipped everything into yolov11n_C2PSA_ENHANCED_COMBINED_2025-06-23_01-22-09.zip

# %% [markdown]
# ### Download From Google Colab

# %%
from google.colab import files
files.download(f"{zip_filename}")

# %% [markdown]
# ### Put in Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

drive_export_dir = Path("/content/drive/MyDrive/FinalYoloExports")
drive_export_dir.mkdir(parents=True, exist_ok=True)

shutil.copy(f"{zip_filename}", drive_export_dir / zip_filename)
print(f"✅ Copied {zip_filename} to Google Drive at {drive_export_dir}")
# Out:
# Mounted at /content/drive
# ✅ Copied yolov11n_C2PSA_ENHANCED_COMBINED_2025-06-23_01-22-09.zip to Google Drive at /content/drive/MyDrive/FinalYoloExports
